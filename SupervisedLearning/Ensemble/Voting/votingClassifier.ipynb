# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import train_test_split,cross_val_score

# %%
df = pd.read_csv("D://Programming//Machine_Learning//MachineLearningAlgo//SupervisedLearning//DataSets//Breast_cancer_dataset.csv")

# %%
target = df["diagnosis"]
features = df.iloc[:,2:-1]
le = LabelEncoder()
target = le.fit_transform(target.ravel())
sc = StandardScaler()
features = sc.fit_transform(features)
target = target.reshape(-1,1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
estimators = [("lr",LogisticRegression(max_iter = 1000,penalty = "l2")),
              ("tree",DecisionTreeClassifier(max_depth=50)),
              ("knn",KNeighborsClassifier(n_neighbors=3))]

# %% [markdown]
# Simple combining tree models

# %%
acc = []
for md in estimators:
    ac = cross_val_score(md[1],features,target,cv = 10,scoring="accuracy")
    acc.append(ac)
np.mean(acc)

# %% [markdown]
# with voting classifier

# %%
model = VotingClassifier(estimators=estimators,voting='soft')
acc = cross_val_score(model,features,target,cv=10,scoring="accuracy")
acc

# %%
np.mean(acc)
