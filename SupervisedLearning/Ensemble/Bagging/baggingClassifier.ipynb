# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score,train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
df = pd.read_csv("D://Programming//Machine_Learning//MachineLearningAlgo//SupervisedLearning//DataSets//Breast_cancer_dataset.csv")
target = df.iloc[:,1]
features = df.iloc[:,2:-1]
le = LabelEncoder()
target = le.fit_transform(target.values)
sc = StandardScaler()
features = sc.fit_transform(features)

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
estimators = [("lr",LogisticRegression(max_iter=1000)),
             ("dt",DecisionTreeClassifier(max_depth=50)),
             ("knn",KNeighborsClassifier(n_neighbors=5)),
             ("svm",SVC(kernel="sigmoid"))]

# %%
for model in estimators:
    print(f"{model[0]} accuracy:",np.mean(cross_val_score(model[1],features,target,cv = 10)))
# Out:
# lr accuracy: 0.9806704260651629
# dt accuracy: 0.9050438596491228
# knn accuracy: 0.9666353383458647
# svm accuracy: 0.9437969924812029

# %%
x_train, x_test, y_train, y_test = train_test_split(
    features, target, test_size=0.2, random_state=42
)

# %%
for model in estimators:
    bg = BaggingClassifier(estimator=model[1],bootstrap=True,n_estimators=50,random_state=42)
    print(f"with base model {model[0]} accuracy:",np.mean(cross_val_score(bg,features,target,cv = 10)))
# Out:
# with base model lr accuracy: 0.9824248120300751
# with base model dt accuracy: 0.9578947368421054
# with base model knn accuracy: 0.9666353383458647
# with base model svm accuracy: 0.9578007518796993

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50,max_depth=50)
print("with base model rf accuracy:",np.mean(cross_val_score(rf,features,target,cv = 10)))
# Out:
# with base model rf accuracy: 0.9631578947368421
