# %% [markdown]
# # ***Linear Regression form scratch***

# %%
import numpy as np 
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %% [markdown]
# # DATA FETCHING

# %%
dataset = pd.read_csv("../DataSets/advertising.csv")
df = dataset[["TV","Sales"]]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %% [markdown]
# # DATA SPLITING

# %% [markdown]
# **Geathering features and corresponding targets**

# %%
feature = df["TV"]
target = df["Sales"]
feature = (feature - np.mean(feature))/np.std(feature)
target = (target - np.mean(target))/np.std(target)
# plt.scatter(feature,target)
# plt.xlabel("TV")
# plt.ylabel("Sales")
# plt.show()

# %% [markdown]
# **spliting** *X_train,Y_train,X_test,Y_test* **from features and targets**

# %%
x_train = feature[:150]
y_train = target[:150]
x_test = feature[150:]
y_test = target[150:]

# %% [markdown]
# # INITIALISATION OF PARAMETERS

# %%
# y = mx + c
m = 0.01
c = 0.01
alpha = 0.001

# %% [markdown]
# # TRAINING

# %%
for epoc in range(10000):
    dm = -2/150 * np.sum(x_train * (y_train - m * x_train - c))
    dc = -2/150 * np.sum(y_train - m * x_train - c)
    m = m - alpha * dm
    c = c - alpha * dc
print("slop : ",m)
print("Intercept : ",c)
# Out:
# slop :  0.9108004996285487
# Intercept :  0.030625100087849935

# %% [markdown]
# # TESTING

# %%
y_pred = m * x_test + c
mse = np.mean((y_pred - y_test) ** 2)
mse = np.sqrt(mse)
mse
# Out:
# np.float64(0.49457376820827603)

# %%
plt.scatter(feature,target)
plt.plot(x_test,y_pred,color = "red")
plt.show()
